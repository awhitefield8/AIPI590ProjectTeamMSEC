# %%
! pip install pandas trfl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Requirement already satisfied: trfl in /usr/local/lib/python3.8/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.8/dist-packages (from trfl) (0.1.7)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.8/dist-packages (from trfl) (1.14.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.8/dist-packages (from trfl) (1.3.0)

# %%
from google.colab import drive, files
import os

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
proj_path ='/content/gdrive/MyDrive/project-recommendations/src/models/' 

os.chdir(proj_path)

# %%
# timer
import time
start_t = time.time()
! python SA2C.py --model=GRU --epoch=15 --data=data_hm --results_path=SA2CResultsHM.csv
duration = time.strftime("%H:%M:%S", time.gmtime(time.time()-start_t))
print(f'time consumed {duration}')

# %%
import time
start_t = time.time()
! python CELossOnly.py --model=GRU --epoch=30 --data=data_hm --results_path=../../CELossOnlyHM.csv
duration = time.strftime("%H:%M:%S", time.gmtime(time.time()-start_t))
print(f'time consumed {duration}')
# Out:
# CELossOnly.py:89: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   tf.compat.v1.nn.rnn_cell.GRUCell (self.hidden_size), # tf.compat.v1.estimator.rnn.GRUCell(self.hidden_size)
# WARNING:tensorflow:From CELossOnly.py:88: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From CELossOnly.py:88: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# CELossOnly.py:216: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output1 = tf.compat.v1.layers.dense(self.states_hidden, self.item_num,
# CELossOnly.py:219: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.output2= tf.compat.v1.layers.dense(self.states_hidden, self.item_num,
# 2022-12-14 03:52:29.237559: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# the loss in 200th batch is: 10.668190
# the loss in 400th batch is: 10.240469
# the loss in 600th batch is: 10.073742
# the loss in 800th batch is: 9.824535
# the loss in 1000th batch is: 9.636365
# the loss in 1200th batch is: 9.240273
# the loss in 1400th batch is: 9.016771
# the loss in 1600th batch is: 8.787837
# the loss in 1800th batch is: 8.248014
# the loss in 2000th batch is: 8.371727
# tcmalloc: large alloc 1851318272 bytes == 0x52476000 @  0x7f192ab891e7 0x7f18f53f114e 0x7f18f5449745 0x7f18f5449878 0x7f18f548f597 0x7f18f54937dc 0x7f18f54e2a72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7f18f5433944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c
# tcmalloc: large alloc 1614995456 bytes == 0xc0a04000 @  0x7f192ab891e7 0x7f18f53f114e 0x7f18f5449745 0x7f18f5449878 0x7f18f548f597 0x7f18f54937dc 0x7f18f54e2a72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7f18f5433944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c
# tcmalloc: large alloc 1684275200 bytes == 0x52476000 @  0x7f192ab891e7 0x7f18f53f114e 0x7f18f5449745 0x7f18f5449878 0x7f18f548f597 0x7f18f54937dc 0x7f18f54e2a72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7f18f5433944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c
# tcmalloc: large alloc 1691205632 bytes == 0xb6ab6000 @  0x7f192ab891e7 0x7f18f53f114e 0x7f18f5449745 0x7f18f5449878 0x7f18f548f597 0x7f18f54937dc 0x7f18f54e2a72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7f18f5433944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c
# #############################################################
# total clicks: 0, total purchase:41673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 536.000000
# clicks hr ndcg @ 5 : 0.000000, 0.000000
# purchase hr and ndcg @5 : 0.012862, 0.009319
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 719.000000
# clicks hr ndcg @ 10 : 0.000000, 0.000000
# purchase hr and ndcg @10 : 0.017253, 0.010733
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 869.000000
# clicks hr ndcg @ 15 : 0.000000, 0.000000
# purchase hr and ndcg @15 : 0.020853, 0.011681
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 997.000000
# clicks hr ndcg @ 20 : 0.000000, 0.000000
# purchase hr and ndcg @20 : 0.023924, 0.012404
# off-line corrected evaluation (click_ng,purchase_ng)@10: 1.000000, 0.001042
# #############################################################
# the loss in 2200th batch is: 8.236284
# the loss in 2400th batch is: 7.732966
# the loss in 2600th batch is: 7.256915
# the loss in 2800th batch is: 7.345487
# the loss in 3000th batch is: 6.967509
# the loss in 3200th batch is: 6.407764
# the loss in 3400th batch is: 6.516787
# the loss in 3600th batch is: 6.381842
# the loss in 3800th batch is: 6.280780
# the loss in 4000th batch is: 5.844034
# tcmalloc: large alloc 1851318272 bytes == 0x52476000 @  0x7f192ab891e7 0x7f18f53f114e 0x7f18f5449745 0x7f18f5449878 0x7f18f548f597 0x7f18f54937dc 0x7f18f54e2a72 0x5aae14 0x5d8416 0x5630f5 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x5d8506 0x7f18f5433944 0x5d814d 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x4997c7 0x5d8868 0x4990ca 0x55cd91 0x55d743 0x642630 0x6426ae 0x644b78 0x64511c
# #############################################################
# total clicks: 0, total purchase:41673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 747.000000
# clicks hr ndcg @ 5 : 0.000000, 0.000000
# purchase hr and ndcg @5 : 0.017925, 0.013307
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 971.000000
# clicks hr ndcg @ 10 : 0.000000, 0.000000
# purchase hr and ndcg @10 : 0.023300, 0.015043
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 1110.000000
# clicks hr ndcg @ 15 : 0.000000, 0.000000
# purchase hr and ndcg @15 : 0.026636, 0.015926
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 1240.000000
# clicks hr ndcg @ 20 : 0.000000, 0.000000
# purchase hr and ndcg @20 : 0.029755, 0.016662
# off-line corrected evaluation (click_ng,purchase_ng)@10: 1.000000, 0.001991
# #############################################################
# the loss in 4200th batch is: 5.739902
# the loss in 4400th batch is: 5.405104
# the loss in 4600th batch is: 5.286817
# the loss in 4800th batch is: 5.150808
# the loss in 5000th batch is: 5.226768
# the loss in 5200th batch is: 5.094014
# the loss in 5400th batch is: 4.359303
# the loss in 5600th batch is: 4.509543
# the loss in 5800th batch is: 4.303828
# the loss in 6000th batch is: 4.339896
# #############################################################
# total clicks: 0, total purchase:41673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 715.000000
# clicks hr ndcg @ 5 : 0.000000, 0.000000
# purchase hr and ndcg @5 : 0.017157, 0.012201
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 941.000000
# clicks hr ndcg @ 10 : 0.000000, 0.000000
# purchase hr and ndcg @10 : 0.022581, 0.013955
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 1120.000000
# clicks hr ndcg @ 15 : 0.000000, 0.000000
# purchase hr and ndcg @15 : 0.026876, 0.015096
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 1228.000000
# clicks hr ndcg @ 20 : 0.000000, 0.000000
# purchase hr and ndcg @20 : 0.029468, 0.015708
# off-line corrected evaluation (click_ng,purchase_ng)@10: 1.000000, 0.002084
# #############################################################
# the loss in 6200th batch is: 4.272053
# the loss in 6400th batch is: 3.743001
# the loss in 6600th batch is: 4.196678
# the loss in 6800th batch is: 4.009124
# the loss in 7000th batch is: 3.953378
# the loss in 7200th batch is: 3.821568
# the loss in 7400th batch is: 3.926282
# the loss in 7600th batch is: 3.803371
# the loss in 7800th batch is: 3.711154
# the loss in 8000th batch is: 3.310147
# #############################################################
# total clicks: 0, total purchase:41673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 617.000000
# clicks hr ndcg @ 5 : 0.000000, 0.000000
# purchase hr and ndcg @5 : 0.014806, 0.010643
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 847.000000
# clicks hr ndcg @ 10 : 0.000000, 0.000000
# purchase hr and ndcg @10 : 0.020325, 0.012414
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 1011.000000
# clicks hr ndcg @ 15 : 0.000000, 0.000000
# purchase hr and ndcg @15 : 0.024260, 0.013453
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 1135.000000
# clicks hr ndcg @ 20 : 0.000000, 0.000000
# purchase hr and ndcg @20 : 0.027236, 0.014154
# off-line corrected evaluation (click_ng,purchase_ng)@10: 1.000000, 0.001939
# #############################################################
# the loss in 8200th batch is: 2.965199
# the loss in 8400th batch is: 3.213265
# the loss in 8600th batch is: 3.356941
# the loss in 8800th batch is: 3.180330
# the loss in 9000th batch is: 3.153676
# the loss in 9200th batch is: 3.172444
# the loss in 9400th batch is: 2.966542
# the loss in 9600th batch is: 2.793015
# the loss in 9800th batch is: 2.923972
# the loss in 10000th batch is: 2.465848
# #############################################################
# total clicks: 0, total purchase:41673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 590.000000
# clicks hr ndcg @ 5 : 0.000000, 0.000000
# purchase hr and ndcg @5 : 0.014158, 0.009905
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 793.000000
# clicks hr ndcg @ 10 : 0.000000, 0.000000
# purchase hr and ndcg @10 : 0.019029, 0.011464
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 922.000000
# clicks hr ndcg @ 15 : 0.000000, 0.000000
# purchase hr and ndcg @15 : 0.022125, 0.012280
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 1063.000000
# clicks hr ndcg @ 20 : 0.000000, 0.000000
# purchase hr and ndcg @20 : 0.025508, 0.013078
# off-line corrected evaluation (click_ng,purchase_ng)@10: 1.000000, 0.001757
# #############################################################
# the loss in 10200th batch is: 3.038856
# the loss in 10400th batch is: 2.535919
# the loss in 10600th batch is: 2.685944
# the loss in 10800th batch is: 2.338188
# the loss in 11000th batch is: 2.654623
# the loss in 11200th batch is: 2.451234
# the loss in 11400th batch is: 2.693880
# the loss in 11600th batch is: 2.490849
# the loss in 11800th batch is: 2.873137
# the loss in 12000th batch is: 2.532442
# #############################################################
# total clicks: 0, total purchase:41673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 527.000000
# clicks hr ndcg @ 5 : 0.000000, 0.000000
# purchase hr and ndcg @5 : 0.012646, 0.008945
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 742.000000
# clicks hr ndcg @ 10 : 0.000000, 0.000000
# purchase hr and ndcg @10 : 0.017805, 0.010604
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 896.000000
# clicks hr ndcg @ 15 : 0.000000, 0.000000
# purchase hr and ndcg @15 : 0.021501, 0.011579
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 1009.000000
# clicks hr ndcg @ 20 : 0.000000, 0.000000
# purchase hr and ndcg @20 : 0.024212, 0.012215
# off-line corrected evaluation (click_ng,purchase_ng)@10: 1.000000, 0.001646
# #############################################################
# the loss in 12200th batch is: 2.828997
# the loss in 12400th batch is: 2.293903
# the loss in 12600th batch is: 2.378059
# the loss in 12800th batch is: 2.090300
# the loss in 13000th batch is: 2.240708
# the loss in 13200th batch is: 2.235847
# the loss in 13400th batch is: 2.417743
# the loss in 13600th batch is: 2.137045
# the loss in 13800th batch is: 2.513884
# the loss in 14000th batch is: 1.741521
# #############################################################
# total clicks: 0, total purchase:41673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 509.000000
# clicks hr ndcg @ 5 : 0.000000, 0.000000
# purchase hr and ndcg @5 : 0.012214, 0.008504
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 690.000000
# clicks hr ndcg @ 10 : 0.000000, 0.000000
# purchase hr and ndcg @10 : 0.016557, 0.009886
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 831.000000
# clicks hr ndcg @ 15 : 0.000000, 0.000000
# purchase hr and ndcg @15 : 0.019941, 0.010782
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 939.000000
# clicks hr ndcg @ 20 : 0.000000, 0.000000
# purchase hr and ndcg @20 : 0.022533, 0.011393
# off-line corrected evaluation (click_ng,purchase_ng)@10: 1.000000, 0.001649
# #############################################################
# the loss in 14200th batch is: 2.317645
# the loss in 14400th batch is: 2.066382
# the loss in 14600th batch is: 2.244289
# the loss in 14800th batch is: 2.298921
# the loss in 15000th batch is: 1.848028
# the loss in 15200th batch is: 0.022409
# the loss in 15400th batch is: 0.023929
# the loss in 15600th batch is: 0.015839
# the loss in 15800th batch is: 0.015070
# the loss in 16000th batch is: 0.015088
# #############################################################
# total clicks: 0, total purchase:41673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 5: 516.000000
# clicks hr ndcg @ 5 : 0.000000, 0.000000
# purchase hr and ndcg @5 : 0.012382, 0.008687
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 10: 701.000000
# clicks hr ndcg @ 10 : 0.000000, 0.000000
# purchase hr and ndcg @10 : 0.016821, 0.010092
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 15: 844.000000
# clicks hr ndcg @ 15 : 0.000000, 0.000000
# purchase hr and ndcg @15 : 0.020253, 0.010994
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cumulative reward @ 20: 945.000000
# clicks hr ndcg @ 20 : 0.000000, 0.000000
# purchase hr and ndcg @20 : 0.022677, 0.011567
# off-line corrected evaluation (click_ng,purchase_ng)@10: 1.000000, 0.001578
# #############################################################
# the loss in 16200th batch is: 0.011267
# the loss in 16400th batch is: 0.012225
# the loss in 16600th batch is: 0.012266
# the loss in 16800th batch is: 0.015880
# the loss in 17000th batch is: 0.015603
# the loss in 17200th batch is: 0.014791
# the loss in 17400th batch is: 0.008007
# time consumed 01:22:35
