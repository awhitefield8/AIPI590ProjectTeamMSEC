# %%
from google.colab import drive, files
import os

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
proj_path ='/content/gdrive/My Drive/project-recommendations/src/models/' 
#proj_path ='/content/gdrive/My Drive/project-recommendations/SA2C_code/Kaggle/' 

#os.listdir(proj_path)
os.chdir(proj_path)

# %%
os.listdir()
# Out:
# ['data_hm',
#  'SASRecModules.py',
#  'split_data.py',
#  'test.py',
#  'utility.py',
#  'NextItNetModules.py',
#  'pop.py',
#  'SNQN.py',
#  '__pycache__',
#  'preprocess_hm.py',
#  'data_rr',
#  'SA2C.py',
#  'preprocess_kaggle.py',
#  'gen_replay_buffer_hm.py']

# %%
os.listdir('data_hm')
# Out:
# ['transactions_train.csv',
#  'sampled_sessions.csv',
#  'sampled_sessions.df',
#  'pop_dict.txt',
#  'sampled_train.df',
#  'sampled_val.df',
#  'sampled_test.df',
#  'replay_buffer.csv']

# %%
! python gen_replay_buffer_hm.py --size 20000 --format csv --data ../data/data_hm/

# %%
! python gen_replay_buffer_hm.py --size 20000 --format paper --data ../data/data_hm/
# Out:
# Start reading all transaction data ...
# Finish reading in 00:00:59
#
# Filter and save all valid sampled data
# gen_replay_buffer_hm.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_sessions['valid_session'] = sampled_sessions.session_id.map(sampled_sessions.groupby('session_id')['item_id'].size() > 2)
# Index(['timestamp', 'session_id', 'item_id', 'price', 'sales_channel_id'], dtype='object')
#
# Start counting popularity ...
# 211141it [00:12, 16307.81it/s]
# Popularity finished in 00:00:13
#
# Start spliting into train, val, test data ...
#
#            Generate Replay Buffer:
#                 Total Session Size : 20000
#                      Train:      14000 ids | 148615 actions
# ...
