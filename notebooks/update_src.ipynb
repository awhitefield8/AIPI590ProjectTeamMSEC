# %% [markdown]
# # Setup

# %% [markdown]
# ### Setup drive and paths

# %%
from google.colab import drive, files
import os

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
proj_path ='/content/gdrive/My Drive/project-recommendations/src/models/' 
#os.listdir(proj_path)
os.chdir(proj_path)

# %% [markdown]
# ### Update existing code
#
# SA2_C source code uses tf1. We update the code to use tf2.

# %%
# !tf_upgrade_v2 \
  --infile '/content/gdrive/My Drive/project-recommendations/old/SA2C_code/Kaggle/SA2C_v2.py' \
  --outfile '/content/gdrive/My Drive/project-recommendations/old/SA2C_code/Kaggle/SA2C_v2_new.py' \
  --reportfile report.txt

# %%
! pip install pandas trfl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 104 kB 16.4 MB/s
# ...

# %%
! python SA2C_v2_new.py --model=GRU --epoch=1
# Out:
# Traceback (most recent call last):
#   File "SA2C_v2_new.py", line 387, in <module>
#     QN_1 = QNetwork(name='QN_1', hidden_size=args.hidden_factor, learning_rate=args.lr, item_num=item_num,
#   File "SA2C_v2_new.py", line 88, in __init__
#     tf.compat.v1.estimator.rnn.GRUCell(self.hidden_size),
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/util/lazy_loader.py", line 59, in __getattr__
#     return getattr(module, item)
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/util/module_wrapper.py", line 232, in _getattr
#     attr = getattr(self._tfmw_wrapped_module, name)
# AttributeError: module 'tensorflow_estimator.python.estimator.api._v1.estimator' has no attribute 'rnn'

# %% [markdown]
# ### Update utilis and SASRec for compatability

# %%
# !tf_upgrade_v2 \
  --infile '/content/gdrive/My Drive/project-recommendations/old/SA2C_code/Kaggle/utility.py' \
  --outfile '/content/gdrive/My Drive/project-recommendations/old/SA2C_code/Kaggle/utility_new.py' \
  --reportfile report.txt
# Out:
# INFO line 28:27: Added keywords to args of function 'tf.shape'
# INFO line 52:9: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# INFO line 56:25: Added keywords to args of function 'tf.nn.moments'
# INFO line 56:25: Renamed keyword argument for tf.nn.moments from keep_dims to keepdims
# TensorFlow 2.0 Upgrade Script
# -----------------------------
# Converted 1 files
# Detected 0 issues that require attention
# --------------------------------------------------------------------------------
#
#
# Make sure to read the detailed log 'report.txt'

# %%
# !tf_upgrade_v2 \
  --infile '/content/gdrive/My Drive/project-recommendations/old/SA2C_code/Kaggle/SASRecModules.py' \
  --outfile '/content/gdrive/My Drive/project-recommendations/old/SA2C_code/Kaggle/SASRecModules_new.py' \
  --reportfile report.txt
# Out:
# INFO line 22:11: Added keywords to args of function 'tf.convert_to_tensor'
# INFO line 90:9: Renamed 'tf.variable_scope' to 'tf.compat.v1.variable_scope'
# WARNING line 91:23: tf.get_variable requires manual check. tf.get_variable returns ResourceVariables by default in 2.0, which have well-defined semantics and are stricter about shapes. You can disable this behavior by passing use_resource=False, or by calling tf.compat.v1.disable_resource_variables().
# INFO line 91:23: Renamed 'tf.get_variable' to 'tf.compat.v1.get_variable'
# INFO line 95:51: Multiplying scale arg of tf.contrib.layers.l2_regularizer by half to what tf.keras.regularizers.l2 expects.
#
# INFO line 99:18: Added keywords to args of function 'tf.nn.embedding_lookup'
# WARNING line 99:18: tf.nn.embedding_lookup requires manual check. `partition_strategy` has been removed from tf.nn.embedding_lookup.  The 'div' strategy will be used by default.
# ...
