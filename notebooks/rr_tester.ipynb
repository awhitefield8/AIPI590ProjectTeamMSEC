# %%
! pip install pandas trfl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 104 kB 13.7 MB/s
# ...

# %%
from google.colab import drive, files
import os

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
proj_path ='/content/gdrive/MyDrive/project-recommendations/src/models/' 

#os.listdir(proj_path)
os.chdir(proj_path)

# %%
import time
start_t = time.time()
! python SA2C.py --model=GRU --epoch=1 --data=../../data/data_rr --results_path=../../results/test.csv
duration = time.strftime("%H:%M:%S", time.gmtime(time.time()-start_t))
print(f'time consumed {duration}')

# %%
import time
start_t = time.time()
! python CELossOnly.py --model=GRU --epoch=1 --data=../../data/data_rr
duration = time.strftime("%H:%M:%S", time.gmtime(time.time()-start_t))
print(f'time consumed {duration}')
# Out:
# python3: can't open file 'CELossOnly.py': [Errno 2] No such file or directory
# time consumed 00:00:00

# %%
import time
start_t = time.time()
! python SA2C.py --model=SASRec --epoch=1 --data=../../data/data_rr --results_path=../../results/test.csv
duration = time.strftime("%H:%M:%S", time.gmtime(time.time()-start_t))
print(f'time consumed {duration}')
# Out:
# SA2C.py:188: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   self.seq = tf.compat.v1.layers.dropout(self.seq,
# /content/gdrive/MyDrive/project-recommendations/src/models/SASRecModules.py:142: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   Q = tf.compat.v1.layers.dense(queries, num_units, activation=None) # (N, T_q, C)
# /content/gdrive/MyDrive/project-recommendations/src/models/SASRecModules.py:143: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   K = tf.compat.v1.layers.dense(keys, num_units, activation=None) # (N, T_k, C)
# ...
